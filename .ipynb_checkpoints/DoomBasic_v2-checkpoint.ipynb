# %%
import gym
import ppaquette_gym_doom
import numpy as np
from ppaquette_gym_doom.wrappers import SetResolution, ToDiscrete
from gym.wrappers import SkipWrapper

# (see https://github.com/ppaquette/gym-doom/blob/master/ppaquette_gym_doom/doom_basic.py)
def create_env():
    return SetResolution('200x150')(
        SkipWrapper(repeat_count=4)(
        ToDiscrete('minimal')(gym.make('ppaquette/DoomBasic-v0'))))

env = create_env()
WIDTH, HEIGHT = env.screen_width, env.screen_height

NOOP, SHOOT, LEFT, RIGHT = 0, 1, 2, 3
SUCCESS = 100 - 10
# Out:
# [2017-02-26 23:10:31,805] Making new env: ppaquette/DoomBasic-v0

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

def show(observation):
    plt.figure(figsize=(8, 6))
    plt.imshow(observation, interpolation=None)
    plt.xticks([]); plt.yticks([]);

show(env.reset())

# %%
observation, reward, _, _ = env.step(action=SHOOT)
print(reward)
show(observation)
# Out:
# -10.0

# %%
from gym import wrappers
from collections import namedtuple
import operator

SARE = namedtuple('SAR', ['state', 'action', 'reward', 'end'])


def play_episodes(env, agent, episode_count=100, max_episode_steps=10000, outdir=None, seed=None):
    if outdir is not None:
        env = wrappers.Monitor(env, directory=outdir, force=True)
    if seed is not None:
        env.seed(seed)

    reward = 0
    done = False

    for i in range(episode_count):
        observation = env.reset()
        while True:
            action = agent.act(observation, reward, done)
            new_observation, reward, done, _ = env.step(action)
            yield SARE(observation, action, reward, done)
            
            if done:
                break
            else:
                observation = new_observation
    env.close()

# %% [markdown]
# ## Off-line Q-learning

# %%
import random


def to_experience_pairs(sares, n_misses=100):
    experiences = [
        (previous_s, a, r, next_s, end)
        for (previous_s, a, r, end), (next_s, _, _, _) in zip(sares[:-1], sares[1:])
    ]

    shuffled_exps = experiences
    if n_misses != None:
        shuffled_exps = random.choices(experiences, k=n_misses) + [e for e in experiences if e[2] >= SUCCESS]
        random.shuffle(shuffled_exps)

    prev_frames, actions, rewards, next_frames, is_ends = zip(*shuffled_exps)
    prev_frames = np.asarray(prev_frames)
    next_frames = np.asarray(next_frames)
    actions = np.asarray(actions)
    rewards = np.asarray(rewards)
    is_ends = np.asarray(is_ends)
    
    print('Training on {}/{} success/total out of {} 1-step experiences with actions distribution {}'.format(
        np.sum(rewards>=SUCCESS),
        len(rewards),
        len(experiences),
        np.bincount(actions)))
    
    return (prev_frames, next_frames, actions, rewards, is_ends)

collecting_agent = StrafingAndRandomlyShootingAgent()

env = create_env()

sares = list(play_episodes(env, collecting_agent, episode_count=10))

prev_frames, next_frames, actions, rewards, is_ends = to_experience_pairs(sares)
# Out:
# [2017-02-26 23:11:13,267] Making new env: ppaquette/DoomBasic-v0
# Training on 9/108 success/total out of 375 1-step experiences with actions distribution [ 0 22 43 43]

# %%
import tensorflow as tf
from keras import backend as K

sess = tf.InteractiveSession()
K.set_session(sess)

# %%
from keras.layers import Dense, Convolution2D, Flatten, Activation
from keras.models import Sequential
from keras.optimizers import Adam

def create_q_model(conv1_weights=None, conv2_weights=None, dense_weights=None):
    model = Sequential()

    model.add(Convolution2D(
        2, nb_row=6, nb_col=6, border_mode='valid', weights=conv1_weights,
        input_shape=[HEIGHT, WIDTH, 3], dim_ordering='tf'))
    model.add(Activation('relu'))
    model.add(Convolution2D(2, nb_row=2, nb_col=2, weights=conv2_weights))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(4, init='normal', activation='linear', weights=dense_weights))

    model.compile(loss='mse', optimizer='adam')
    
    return model

def copy_model(model):
    conv1_weights =  [w.eval() for w in model.layers[0].weights]
    conv2_weights = [w.eval() for w in model.layers[2].weights]
    dense_weights = [w.eval() for w in model.layers[5].weights]
    return create_q_model(conv1_weights, conv2_weights, dense_weights)


acting_model = create_q_model()
target_model = create_q_model()

# %%
def sares_to_input_targets(model, sares, gamma = 1, reward_clip=20, n_misses=100):
    prev_frames, next_frames, actions, rewards, is_ends = to_experience_pairs(sares, n_misses)
    n_samples = len(actions)
    
    current_action_rewards = model.predict(prev_frames)
    target_action_rewards = current_action_rewards.copy()

    followed_action_targets = np.clip(rewards, -np.inf, reward_clip) + gamma * (1 - is_ends) * model.predict(next_frames).max(axis=1)
    target_action_rewards[np.arange(n_samples), actions] = followed_action_targets

    return prev_frames, target_action_rewards

# %%
class EpsilonGreedyQAgent(object):
    def __init__(self, model, epsilon=.05):
        self.model = model
        self.epsilon = epsilon

    def act(self, observation, reward, done):
        if random.uniform(0, 1) <= self.epsilon:
            return random.choice([NOOP, SHOOT, LEFT, RIGHT])
        else:
            return self.model.predict(observation[np.newaxis])[0].argmax()

BATCH_SIZE = 64

env = create_env()

for _ in range(1):
    for _ in range(3):
        sares = list(play_episodes(env, EpsilonGreedyQAgent(acting_model), episode_count=5))
        prev_frames, target_action_rewards = sares_to_input_targets(target_model, sares, n_misses=500)
        acting_model.fit(x=prev_frames, y=target_action_rewards, batch_size=BATCH_SIZE, nb_epoch=1, verbose=1)
    #target_model = copy_model(acting_model)
# Out:
# [2017-02-26 23:28:54,680] Making new env: ppaquette/DoomBasic-v0
# Training on 0/500 success/total out of 349 1-step experiences with actions distribution [  6 252 157  85]
# Epoch 1/1
# 500/500 [==============================] - 6s - loss: 8.3608
# Training on 5/501 success/total out of 337 1-step experiences with actions distribution [ 19  21 297 164]
# Epoch 1/1
# 501/501 [==============================] - 6s - loss: 6.7338
# Training on 3/501 success/total out of 217 1-step experiences with actions distribution [188  31  26 256]
# Epoch 1/1
# 501/501 [==============================] - 6s - loss: 6.1402

# %%
success_indexes, = np.where(target_action_rewards.max(1) >= 15)
success_index = np.random.choice(success_indexes)
success_test_frame = prev_frames[success_index, :]

show(success_test_frame)
print(target_action_rewards[success_index])
print(acting_model.predict(success_test_frame[np.newaxis])[0])
print(target_model.predict(success_test_frame[np.newaxis])[0])
# Out:
# [ -2.21082211  20.          -1.11298358  -2.96077371]
# [-3.68482113 -3.07883668 -3.35444498 -4.70367384]
# [-2.21082187 -1.83899462 -1.11298358 -2.96077371]

# %%
no_success_indexes, = np.where(target_action_rewards.max(1) != SUCCESS)
no_succcess_index = np.random.choice(no_success_indexes)
no_success_frame = prev_frames[no_succcess_index, :]
show(no_success_frame)
print(target_action_rewards[no_succcess_index])
print(acting_model.predict(no_success_frame[np.newaxis])[0])
print(target_model.predict(no_success_frame[np.newaxis])[0])
# Out:
# [ -8.56445312  -6.56486988  -5.32602072 -10.43444061]
# [-8.21253395 -6.85700941 -7.07471132 -8.07042027]
# [-8.56445503 -6.56487036 -5.32602072 -7.48144007]

# %%
n_episodes = 10
seed = 0

env = create_env()

sares = play_episodes(env, EpsilonGreedyQAgent(acting_model), episode_count=n_episodes, seed=seed, outdir='tmp/q_learning')
print('EpsilonGreedyQAgent average reward of {:.2f}'.format(sum(map(operator.attrgetter('reward'), sares))))
# Out:
# [2017-02-26 23:31:03,191] Making new env: ppaquette/DoomBasic-v0
# [2017-02-26 23:31:03,204] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-02-26 23:31:03,205] Clearing 8 monitor files from previous run (because force=True was provided)
# [2017-02-26 23:31:03,520] Starting new video recorder writing to /Users/gui/Dev/rl-study/tmp/q_learning/openaigym.video.0.3754.video000000.mp4
# [2017-02-26 23:31:04,214] Starting new video recorder writing to /Users/gui/Dev/rl-study/tmp/q_learning/openaigym.video.0.3754.video000001.mp4
# [2017-02-26 23:31:06,315] Starting new video recorder writing to /Users/gui/Dev/rl-study/tmp/q_learning/openaigym.video.0.3754.video000008.mp4
# [2017-02-26 23:31:07,024] Finished writing results. You can upload them to the scoreboard via gym.upload('/Users/gui/Dev/rl-study/tmp/q_learning')
# EpsilonGreedyQAgent average reward of -2023.00
